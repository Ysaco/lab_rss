# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser
import pandas as pd

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
parsed = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
parsed.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
list((parsed['feed']).keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'subtitle',
#  'subtitle_detail',
#  'updated',
#  'updated_parsed',
#  'language',
#  'sy_updateperiod',
#  'sy_updatefrequency',
#  'generator_detail',
#  'generator']

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
title = parsed['feed']['title']
subtitle = parsed['feed']['subtitle']
author = parsed['feed']['generator']
link = parsed['feed']['link']

a = (title + '. ' + subtitle + '. ' + author + '. ' + link)
a
# Out:
# 'Radar. Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology. https://wordpress.org/?v=5.3.14. https://www.oreilly.com/radar'

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(parsed['entries'])
# Out:
# 15

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
list(parsed['entries'][0].keys())
# Out:
# ['title',
#  'title_detail',
#  'links',
#  'link',
#  'comments',
#  'published',
#  'published_parsed',
#  'authors',
#  'author',
#  'author_detail',
#  'tags',
#  'id',
#  'guidislink',
#  'summary',
#  'summary_detail',
#  'content',
#  'wfw_commentrss',
#  'slash_comments']

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
title_li = [i['title'] for i in parsed['entries']]
title_li
# Out:
# ['Radar Trends to Watch: December 2022',
#  'AI’s ‘SolarWinds Moment’ Will Occur; It’s Just a Matter of When',
#  'Technical Health Isn’t Optional',
#  'Healthy Data',
#  'Formal Informal Languages',
#  'Radar Trends to Watch: November 2022',
#  'What We Learned Auditing Sophisticated AI for Bias',
#  'The Collaborative Metaverse',
#  'What Is Hyperautomation?',
#  'Radar Trends to Watch: October 2022',
#  'The Problem with Intelligence',
#  'Radar Trends to Watch: September 2022',
#  'Ad Networks and Content Marketing',
#  'On Technique',
#  'Scaling False Peaks']

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
trends = [i for i in title_li if 'Radar Trends to Watch' in i]
percentage = (len(trends)*100)/len(titles)
percentage
# Out:
# 26.666666666666668

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
df = pd.DataFrame(parsed['entries'])
df
# Out:
#                                                 title  \
# 0                Radar Trends to Watch: December 2022
# 1   AI’s ‘SolarWinds Moment’ Will Occur; It’s Just...
# 2                     Technical Health Isn’t Optional
# 3                                        Healthy Data
# 4                           Formal Informal Languages
# 5                Radar Trends to Watch: November 2022
# 6   What We Learned Auditing Sophisticated AI for ...
# 7                         The Collaborative Metaverse
# 8                            What Is Hyperautomation?
# 9                 Radar Trends to Watch: October 2022
# 10                      The Problem with Intelligence
# 11              Radar Trends to Watch: September 2022
# 12                  Ad Networks and Content Marketing
# 13                                       On Technique
# 14                                Scaling False Peaks
#
#                                          title_detail  \
# ...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df1 = df.groupby(['author'])['author'].count()
a = df1.sort_values(ascending=False)
a
# Out:
# author
# Mike Loukides    11
# Kevlin Henney     1
# Mike Barlow       1
# Patrick Hall      1
# Q McCallum        1
# Name: author, dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
title_len = ([len(i) for i in titles])
title_len

df['title_len'] = title_len
df.sort_values('title_len', ascending=False)
# Out:
#                                                 title  \
# 1   AI’s ‘SolarWinds Moment’ Will Occur; It’s Just...
# 6   What We Learned Auditing Sophisticated AI for ...
# 11              Radar Trends to Watch: September 2022
# 0                Radar Trends to Watch: December 2022
# 5                Radar Trends to Watch: November 2022
# 9                 Radar Trends to Watch: October 2022
# 12                  Ad Networks and Content Marketing
# 2                     Technical Health Isn’t Optional
# 10                      The Problem with Intelligence
# 7                         The Collaborative Metaverse
# 4                           Formal Informal Languages
# 8                            What Is Hyperautomation?
# 14                                Scaling False Peaks
# 3                                        Healthy Data
# 13                                       On Technique
#
#                                          title_detail  \
# ...

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
b = [i['title'] for i in parsed['entries'] if 'machine learning' in i['summary']]
b
# Out:
# ['Radar Trends to Watch: October 2022']
